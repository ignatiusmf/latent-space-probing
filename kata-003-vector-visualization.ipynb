# %% [markdown]
# # ROUND 4

# %%
import torch
from matplotlib import pyplot as plt
from rich import print as pprint

# torch.manual_seed(0)

N = 10
n = 2

X = torch.randn(N,n)
Xc = X - X.mean(0, keepdim=True)
pprint(Xc)

for i in range(N):
  plt.quiver(0, 0, Xc[i,0], Xc[i,1], scale=5)

plt.gca() # I HAVE TO SCALE THIS THING SO IT MAKES SENSE VISUALLY
plt.show()


A, B, C = torch.linalg.svd(Xc, full_matrices=False)
pprint('A', A,'B', B,'C',C)

# %%
k = 1
X_proj = Xc @ C[:, :k]
pprint(X_proj)
X_recon = X_proj @ C[:, :k].T
pprint(X_recon)

for i in range(N):
  plt.quiver(0, 0, X_recon[i,0], X_recon[i,1],scale=5)

# %%
Ck = C[:, :k]
Ckt = Ck.T
pprint(Ck)
pprint(Ckt)

plt.quiver(0, 0, Ck[0], Ck[1], scale=5)
plt.quiver(0,0,Ckt[0,1],Ckt[0,0] , scale=1)

# %%
import plotly.graph_objects as go
import numpy as np

v = np.array([1, 2, 3])

fig = go.Figure()
fig.add_trace(go.Cone(
    x=[0], y=[0], z=[0],
    u=[v[0]], v=[v[1]], w=[v[2]],
    sizemode="absolute"
))
fig.show()

# %% [markdown]
# # Round 5

# %%
import torch
import numpy as np
from matplotlib import pyplot as plt
from rich import print as pprint

np.random.seed(1)

N = 10
n = 3
X = np.random.randn(N,n)
Xc = X - X.mean(0, keepdims=True)

for i in range(N):
  plt.quiver(0, 0, Xc[i, 0], Xc[i, 1], scale=1, angles='xy', scale_units='xy')

pprint(Xc)
plt.gca().set_aspect('equal', adjustable='box')
plt.xlim(-3, 3)
plt.ylim(-3, 3)

plt.show()

# %% [markdown]
# # ROUND 6

# %%
import torch 
import numpy as np
from matplotlib import pyplot as plt

np.random.seed(0)

N = 10
n = 3
X = np.random.randn(N, n)
Xc = X - X.mean(0, keepdims=True)

for i, v in enumerate(Xc):
  plt.quiver(0, 0, v[0], v[1], scale=1, angles='xy', scale_units='xy') # DAAR MOET NOG GOED DAAR BINNE KOM?
plt.gca().set_aspect('equal', adjustable='box')
plt.xlim(-2.5,2.5)
plt.ylim(-2.5,2.5)

plt.show()

A, B, C = np.linalg.svd(Xc, full_matrices=False)
k = 3
pprint(Xc)
pprint(C)

Xp = Xc @ C
Xr = Xp[:, :k] @ C[:, :k].T

plt.figure(figsize=(5,5))
plt.subplot(1,3,1)
plt.matshow(Xc,fignum=False)

plt.subplot(1,3,2)
plt.matshow(Xp,fignum=False)

plt.subplot(1,3,3)
plt.matshow(Xr,fignum=False)



plt.tight_layout()
plt.show()
# Out:
# [[ 8.13092187e-01  3.66624333e-03  9.97619766e-01]
#  [ 1.28993304e+00  1.47106703e+00 -9.58396098e-01]
#  [-8.71741295e-04 -5.47848173e-01 -8.43370697e-02]
#  [-5.40361657e-01 -2.52447394e-01  1.47315529e+00]
#  [-1.89922434e-01 -2.74815949e-01  4.62745015e-01]
#  [-6.17285831e-01  1.09758811e+00 -1.86276482e-01]
#  [-6.37892457e-01 -1.25058670e+00 -2.53410803e+00]
#  [-2.97341563e-01  4.67945234e-01 -7.23283238e-01]
#  [ 1.31879447e+00 -1.85085664e+00  6.46402994e-02]
#  [-1.13814401e+00  1.13628825e+00  1.48824055e+00]]
# [[-0.19269581  0.4867844   0.8520031 ]
#  [ 0.29186142 -0.80054653  0.52339485]
#  [-0.93684857 -0.34952283 -0.01218837]]
